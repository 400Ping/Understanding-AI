# %%
f = open("Iris.csv", "r")
reader = csv.reader(f)
for row in reader:
    print(row)
# Out:
# ['Type', 'sl', 'sw', 'pl', 'pw']
# ['Setosa', '5', '3', '1.6', '0.2']
# ['Setosa', '5', '3.4', '1.6', '0.4']
# ['Setosa', '5.2', '3.5', '1.5', '0.2']
# ['Setosa', '5.2', '3.4', '1.4', '0.2']
# ['Setosa', '4.7', '3.2', '1.6', '0.2']
# ['Setosa', '4.8', '3.1', '1.6', '0.2']
# ['Setosa', '5.4', '3.4', '1.5', '0.4']
# ['Setosa', '5.2', '4.1', '1.5', '0.1']
# ['Setosa', '5.5', '4.2', '1.4', '0.2']
# ['Setosa', '4.9', '3.1', '1.5', '0.1']
# ['Setosa', '5', '3.2', '1.2', '0.2']
# ['Setosa', '5.5', '3.5', '1.3', '0.2']
# ['Setosa', '4.9', '3.1', '1.5', '0.1']
# ['Setosa', '4.4', '3', '1.3', '0.2']
# ['Setosa', '5.1', '3.4', '1.5', '0.2']
# ['Setosa', '5', '3.5', '1.3', '0.3']
# ['Setosa', '4.5', '2.3', '1.3', '0.3']
# ['Setosa', '4.4', '3.2', '1.3', '0.2']
# ['Setosa', '5', '3.5', '1.6', '0.6']
# ['Setosa', '5.1', '3.8', '1.9', '0.4']
# ['Setosa', '4.8', '3', '1.4', '0.3']
# ['Setosa', '5.1', '3.8', '1.6', '0.2']
# ['Setosa', '4.6', '3.2', '1.4', '0.2']
# ...

# %%
import numpy as np
import pandas as pd

# Load the IRIS dataset
iris_data = pd.read_csv('Iris.csv')

# Extract features and species
features = iris_data[['sl', 'sw', 'pl', 'pw']].values
species = iris_data['Type'].unique()

# Create a 3D array to store the reshaped data
reshaped_data = np.zeros((3, 4, 25))

# Reshape the data for each species
for i, specie in enumerate(species):
    specie_data = iris_data[iris_data['Type'] == specie][['sl', 'sw', 'pl', 'pw']].values[:25]
    reshaped_data[i] = specie_data.T

# Print the reshaped data
for i, specie in enumerate(species):
    print(f"\nData for {specie}:")
    print(reshaped_data[i])
# Out:
# Data for Setosa:
# [[5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.  5.5 4.9 4.4 5.1 5.  4.5 4.4
#   5.  5.1 4.8 5.1 4.6 5.3 5. ]
#  [3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2 3.5 3.1 3.  3.4 3.5 2.3 3.2
#   3.5 3.8 3.  3.8 3.2 3.7 3.3]
#  [1.6 1.6 1.5 1.4 1.6 1.6 1.5 1.5 1.4 1.5 1.2 1.3 1.5 1.3 1.5 1.3 1.3 1.3
#   1.6 1.9 1.4 1.6 1.4 1.5 1.4]
#  [0.2 0.4 0.2 0.2 0.2 0.2 0.4 0.1 0.2 0.1 0.2 0.2 0.1 0.2 0.2 0.3 0.3 0.2
#   0.6 0.4 0.3 0.2 0.2 0.2 0.2]]
#
# Data for Versicolor:
# [[6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5 5.5 6.1 5.8
#   5.  5.6 5.7 5.7 6.2 5.1 5.7]
#  [3.  2.8 3.  2.9 2.6 2.4 2.4 2.7 2.7 3.  3.4 3.1 2.3 3.  2.5 2.6 3.  2.6
#   2.3 2.7 3.  2.9 2.9 2.5 2.8]
#  [4.4 4.8 5.  4.5 3.5 3.8 3.7 3.9 5.1 4.5 4.5 4.7 4.4 4.1 4.  4.4 4.6 4.
#   3.3 4.2 4.2 4.2 4.3 3.  4.1]
#  [1.4 1.4 1.7 1.5 1.  1.1 1.  1.2 1.6 1.5 1.6 1.5 1.3 1.3 1.3 1.2 1.4 1.2
#   1.  1.3 1.2 1.3 1.3 1.1 1.3]]
#
# Data for Verginica:
# ...

# %%
import numpy as np
import pandas as pd

# Load the IRIS dataset
iris_data = pd.read_csv('Iris.csv')

# Extract features and species
features = iris_data[['sl', 'sw', 'pl', 'pw']].values
species = iris_data['Type'].unique()

# Create a 3D array to store the reshaped data
reshaped_data = np.zeros((3, 4, 25))

# Reshape the data for each species
for i, specie in enumerate(species):
    specie_data = iris_data[iris_data['Type'] == specie][['sl', 'sw', 'pl', 'pw']].values[:25]
    reshaped_data[i] = specie_data.T

# Calculate averages, maximums, and minimums
for i, specie in enumerate(species):
    print(f"\nStatistics for {specie}:")
    
    # Averages
    averages = np.mean(reshaped_data[i], axis=1)
    print("Averages (sl, sw, pl, pw):", averages)
    
    # Maximums
    maximums = np.max(reshaped_data[i], axis=1)
    print("Maximums (sl, sw, pl, pw):", maximums)
    
    # Minimums
    minimums = np.min(reshaped_data[i], axis=1)
    print("Minimums (sl, sw, pl, pw):", minimums)
# Out:
# Statistics for Setosa:
# Averages (sl, sw, pl, pw): [4.984 3.356 1.468 0.24 ]
# Maximums (sl, sw, pl, pw): [5.5 4.2 1.9 0.6]
# Minimums (sl, sw, pl, pw): [4.4 2.3 1.2 0.1]
#
# Statistics for Versicolor:
# Averages (sl, sw, pl, pw): [5.86  2.764 4.208 1.308]
# Maximums (sl, sw, pl, pw): [6.8 3.4 5.1 1.7]
# Minimums (sl, sw, pl, pw): [5.  2.3 3.  1. ]
#
# Statistics for Verginica:
# Averages (sl, sw, pl, pw): [6.6   3.02  5.464 2.008]
# Maximums (sl, sw, pl, pw): [7.9 3.8 6.4 2.5]
# Minimums (sl, sw, pl, pw): [5.8 2.5 4.8 1.4]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the IRIS dataset
iris_data = pd.read_csv('Iris.csv')

# Create the scatter plot
plt.figure(figsize=(10, 6))

# Plot each species with a different color
species = iris_data['Type'].unique()
colors = ['blue', 'green', 'red']

for i, specie in enumerate(species):
    specie_data = iris_data[iris_data['Type'] == specie]
    plt.scatter(specie_data['sl'], specie_data['pl'], 
                c=colors[i], label=specie, alpha=0.7)

# Customize the plot
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Iris Data', fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Pizza-simp.csv file
pizza_data = pd.read_csv('Pizza-simp.csv')

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Colors for each pizza brand
colors = ['red', 'blue', 'green', 'orange', 'purple']

# Scatter plot for Protein vs. Fat
for i, brand in enumerate(pizza_data['brand'].unique()):
    brand_data = pizza_data[pizza_data['brand'] == brand]
    ax1.scatter(brand_data['f'], brand_data['p'], c=colors[i], label=brand, alpha=0.7)

ax1.set_xlabel('Fat')
ax1.set_ylabel('Protein')
ax1.set_title('Protein vs. Fat in Pizza Brands')
ax1.legend()

# Scatter plot for Sugar vs. Sodium
for i, brand in enumerate(pizza_data['brand'].unique()):
    brand_data = pizza_data[pizza_data['brand'] == brand]
    ax2.scatter(brand_data['so'], brand_data['su'], c=colors[i], label=brand, alpha=0.7)

ax2.set_xlabel('Sodium')
ax2.set_ylabel('Sugar')
ax2.set_title('Sugar vs. Sodium in Pizza Brands')
ax2.legend()

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
